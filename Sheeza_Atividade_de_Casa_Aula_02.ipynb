# %% [markdown]
# <a href="https://colab.research.google.com/github/sheezarainbow9/Notebooks/blob/main/Sheeza_Atividade_de_Casa_Aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Dados obtidos por requisição de url disponível no site http://dados.recife.pe.gov.br/tl/dataset/relacao-de-pessoas-vacinadas-covid-19/resource/966e9c4c-df45-40d7-9c58-2f13c61a6d28 

df = pd.read_csv('http://dados.recife.pe.gov.br/dataset/f381d9ea-4839-44a6-b4fe-788239189900/resource/966e9c4c-df45-40d7-9c58-2f13c61a6d28/download/vacinados.csv', sep=";")

# %%
df.shape
# Out:
# (3402890, 9)

# %%
df.head()
# Out:
#               cpf                           nome       sexo  \
# 0  ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1  ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
#
#                                    grupo  \
# 0  TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1  TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 2                 TRABALHADORES DA SAÚDE
# 3                 TRABALHADORES DA SAÚDE
# 4                 TRABALHADORES DA SAÚDE
#
#                                               vacina         lote  dose  \
# 0  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)  219VCD270W    2.0
# 1  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)   216VCD206Z   1.0
# 2                 1 - CORONAVAC - SINOVAC (BUTANTAN)       210043   2.0
# ...

# %%
df.head(10)
# Out:
#               cpf                                   nome       sexo  \
# 0  ***.574.544-**              AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1  ***.574.544-**              AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2  ***.886.964-**          AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3  ***.886.964-**          AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4  ***.886.964-**          AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 5  ***.435.684-**  AANA JULIA RAMOS SOARES DE BRITO LIRA   FEMININO
# 6  ***.435.684-**  AANA JULIA RAMOS SOARES DE BRITO LIRA   FEMININO
# 7  ***.405.524-**       AANA MAYARA DA SILVA DE OLIVEIRA   FEMININO
# 8  ***.405.524-**       AANA MAYARA DA SILVA DE OLIVEIRA   FEMININO
# 9  ***.876.664-**       AANDRESSA VASCONCELOS DOS SANTOS   FEMININO
#
#                                    grupo  \
# 0  TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1  TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 2                 TRABALHADORES DA SAÚDE
# 3                 TRABALHADORES DA SAÚDE
# ...

# %%
df.tail()
# Out:
#                     cpf                        nome       sexo   grupo  \
# 3407293  ***.619.454-**  NECIRA FERREIRA DE SANTANA   FEMININO  IDOSOS
# 3407294  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407295  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407296  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407297             NaN                         NaN        NaN     NaN
#
#                                      vacina     lote  dose data_vacinacao  \
# 3407293              3 - COMIRNATY (PFIZER)   FF8848   3.0     2021-09-29
# 3407294  1 - CORONAVAC - SINOVAC (BUTANTAN)  210052A   2.0     2021-03-11
# 3407295              3 - COMIRNATY (PFIZER)   FF8848   3.0     2021-09-29
# 3407296  1 - CORONAVAC - SINOVAC (BUTANTAN)   210016   1.0     2021-02-17
# 3407297                                 NaN      NaN   NaN            NaN
#
#                                 local_vacinacao
# ...

# %%
df.tail(10)
# Out:
#                     cpf                              nome       sexo  \
# 3407288  ***.184.254-**  ZYON ALECKSANO DE OLIVEIRA SILVA  MASCULINO
# 3407289  ***.935.244-**             ZYON FERREIRA RIBEIRO  MASCULINO
# 3407290  ***.935.244-**             ZYON FERREIRA RIBEIRO  MASCULINO
# 3407291  ***.619.454-**        NECIRA FERREIRA DE SANTANA   FEMININO
# 3407292  ***.619.454-**        NECIRA FERREIRA DE SANTANA   FEMININO
# 3407293  ***.619.454-**        NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**        SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**        SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**        SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                               NaN        NaN
#
#                                    grupo                              vacina  \
# 3407288  PÚBLICO EM GERAL (18 a 59 anos)  1 - CORONAVAC - SINOVAC (BUTANTAN)
# ...

# %%
df.describe()
# Out:
#                dose
# count  3.407297e+06
# mean   1.723100e+00
# std    7.341606e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    2.000000e+00
# max    4.000000e+00

# %%
df.isnull()
# Out:
#            cpf   nome   sexo  grupo  vacina   lote   dose  data_vacinacao  \
# 0        False  False  False  False   False  False  False           False
# 1        False  False  False  False   False  False  False           False
# 2        False  False  False  False   False  False  False           False
# 3        False  False  False  False   False  False  False           False
# 4        False  False  False  False   False  False  False           False
# ...        ...    ...    ...    ...     ...    ...    ...             ...
# 3407293  False  False  False  False   False  False  False           False
# 3407294  False  False  False  False   False  False  False           False
# 3407295  False  False  False  False   False  False  False           False
# 3407296  False  False  False  False   False  False  False           False
# 3407297   True   True   True   True    True   True   True            True
#
#          local_vacinacao
# 0                  False
# 1                  False
# ...

# %%
df.isnull().sum()
# Out:
# cpf                4060
# nome                  1
# sexo                256
# grupo                 1
# vacina                1
# lote                 94
# dose                  1
# data_vacinacao        1
# local_vacinacao       1
# dtype: int64

# %%
df.fillna
# Out:
# <bound method DataFrame.fillna of                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
df2 = df.copy()

# %%
df.dropna(inplace = True)
df
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407292  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
df2
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
df3 = df2.drop(index = [3407297])
df3
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407292  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
df2.nome.unique()
# Out:
# array(['AABAN VASCONCELOS ZYZZYAG', 'AAMANDA MARIA FREIRE DA SILVA',
#        'AANA JULIA RAMOS SOARES DE BRITO LIRA', ...,
#        'ZYON FERREIRA RIBEIRO', 'NECIRA FERREIRA DE SANTANA', nan],
#       dtype=object)

# %%
df2.columns.unique()
# Out:
# Index(['cpf', 'nome', 'sexo', 'grupo', 'vacina', 'lote', 'dose',
#        'data_vacinacao', 'local_vacinacao'],
#       dtype='object')

# %%
df2.sort_values(by = 'nome')
# Out:
#                     cpf                             nome       sexo  \
# 1839873  ***.081.444-**            ?ENI FERREIRA BARBOSA   FEMININO
# 1839874  ***.081.444-**            ?ENI FERREIRA BARBOSA   FEMININO
# 1839875  ***.081.444-**            ?ENI FERREIRA BARBOSA   FEMININO
# 1351764  ***.005.604-**    ?VO ANTONIO LIBERATO DA SILVA  MASCULINO
# 1351763  ***.005.604-**    ?VO ANTONIO LIBERATO DA SILVA  MASCULINO
# ...                 ...                              ...        ...
# 3235456  ***.110.914-**   ÚRSULA MYRTES NASCIMENTO GOMES   FEMININO
# 3235455  ***.110.914-**   ÚRSULA MYRTES NASCIMENTO GOMES   FEMININO
# 3235454  ***.110.914-**   ÚRSULA MYRTES NASCIMENTO GOMES   FEMININO
# 3235492  ***.736.864-**  ÚRSULLA ROBERTA MACHADO BEZERRA   FEMININO
# 3407297             NaN                              NaN        NaN
#
#                           grupo  \
# 1839873                  IDOSOS
# 1839874                  IDOSOS
# 1839875                  IDOSOS
# ...

# %%
df2.rename(columns = {'sexo': 'genero'}, inplace = True)
df2
# Out:
#                     cpf                           nome     genero  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
df2.index.value_counts().sum()
# Out:
# 3407298

# %%
df2 = df2.fillna({'lote': 0.0})

# %%
df2 = df2.fillna({'genero': 0.0})

# %%
df2 = df2.fillna({'nome': 0.0})

# %%
df2 = df2.fillna({'grupo': 0.0})

# %%
df2 = df2.fillna({'vacina': 0.0})

# %%
df2 = df2.fillna({'dose': 0.0})

# %%
df2 = df2.fillna({'data_vacinacao': 0.0})

# %%
df2 = df2.fillna({'local_vacinacao': 0.0})

# %%
df2.isnull().sum()
# Out:
# cpf                4060
# nome                  0
# genero                0
# grupo                 0
# vacina                0
# lote                  0
# dose                  0
# data_vacinacao        0
# local_vacinacao       0
# dtype: int64
